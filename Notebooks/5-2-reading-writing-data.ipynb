# %%
import pandas as pd

# %% [markdown]
# # Reading and writing data

# %% [markdown]
# Pandas can read data from many formats

# %% [markdown]
# A common format is 'csv', short for comma-separated values. These are just what they say they are: tabular data, arranged in rows, where each column is separated by a comma

# %% [markdown]
# Read a csv file with the `pd.read_csv()` method

# %% [markdown]
# 1. from an online source:

# %%
pd.read_csv('https://data.cityofnewyork.us/resource/c3uy-2p5r.csv')
# Out:
#      unique_id  indicator_id                     name measure measure_info  \
# 0       827029           386               Ozone (O3)    Mean          ppb
# 1       827082           386               Ozone (O3)    Mean          ppb
# 2       827136           386               Ozone (O3)    Mean          ppb
# 3       823412           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 4       827080           386               Ozone (O3)    Mean          ppb
# ..         ...           ...                      ...     ...          ...
# 995     741041           375   Nitrogen dioxide (NO2)    Mean          ppb
# 996     741083           375   Nitrogen dioxide (NO2)    Mean          ppb
# 997     742442           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 998     743709           386               Ozone (O3)    Mean          ppb
# 999     741017           375   Nitrogen dioxide (NO2)    Mean          ppb
#
#     geo_type_name  geo_join_id                        geo_place_name  \
# 0              CD          208         Riverdale and Fieldston (CD8)
# 1           UHF34          102                       Northeast Bronx
# 2           UHF42          201                            Greenpoint
# 3           UHF34          211               Williamsburg - Bushwick
# 4           UHF34          104                  Pelham - Throgs Neck
# ..            ...          ...                                   ...
# 995         UHF34          204                         East New York
# 996         UHF34          403                  Flushing - Clearview
# 997            CD          205  Fordham and University Heights (CD5)
# 998         UHF42          211               Williamsburg - Bushwick
# 999         UHF42          504             South Beach - Tottenville
#
#      time_period               start_date  data_value  message
# 0    Summer 2022  2022-06-01T00:00:00.000        30.2      NaN
# 1    Summer 2022  2022-06-01T00:00:00.000        32.2      NaN
# 2    Summer 2022  2022-06-01T00:00:00.000        32.4      NaN
# 3    Summer 2022  2022-06-01T00:00:00.000         7.0      NaN
# 4    Summer 2022  2022-06-01T00:00:00.000        33.3      NaN
# ..           ...                      ...         ...      ...
# 995  Summer 2021  2021-06-01T00:00:00.000        10.8      NaN
# 996  Summer 2021  2021-06-01T00:00:00.000        11.7      NaN
# 997  Summer 2021  2021-06-01T00:00:00.000         8.7      NaN
# 998  Summer 2021  2021-06-01T00:00:00.000        29.3      NaN
# 999  Summer 2021  2021-06-01T00:00:00.000         5.4      NaN
#
# [1000 rows x 12 columns]

# %% [markdown]
# 2. from a file on your computer, specified by the file path:

# %%
pd.read_csv("C:/Users/dlevine/Downloads/Air_Quality_20250311.csv")
# Out:
#        Unique ID  Indicator ID                                   Name  \
# 0         179772           640  Boiler Emissions- Total SO2 Emissions
# 1         221956           386                             Ozone (O3)
# 2         221806           386                             Ozone (O3)
# 3         221836           386                             Ozone (O3)
# 4         221812           386                             Ozone (O3)
# ...          ...           ...                                    ...
# 18020     816914           643          Annual vehicle miles traveled
# 18021     816913           643          Annual vehicle miles traveled
# 18022     816872           643          Annual vehicle miles traveled
# 18023     816832           643          Annual vehicle miles traveled
# 18024     151658           643          Annual vehicle miles traveled
#
#               Measure     Measure Info Geo Type Name  Geo Join ID  \
# 0      Number per km2           number         UHF42        409.0
# 1                Mean              ppb         UHF34     305307.0
# 2                Mean              ppb         UHF34        103.0
# 3                Mean              ppb         UHF34        204.0
# 4                Mean              ppb         UHF34        104.0
# ...               ...              ...           ...          ...
# 18020   Million miles  per square mile            CD        503.0
# 18021   Million miles  per square mile            CD        503.0
# 18022   Million miles  per square mile         UHF42        208.0
# 18023   Million miles  per square mile         UHF42        407.0
# 18024   Million miles  per square mile         UHF42        408.0
#
#                           Geo Place Name  Time Period  Start_Date  Data Value  \
# 0                       Southeast Queens         2015  01/01/2015         0.3
# 1               Upper East Side-Gramercy  Summer 2014  06/01/2014        24.9
# 2                     Fordham - Bronx Pk  Summer 2014  06/01/2014        30.7
# 3                          East New York  Summer 2014  06/01/2014        32.0
# 4                   Pelham - Throgs Neck  Summer 2014  06/01/2014        31.9
# ...                                  ...          ...         ...         ...
# 18020  Tottenville and Great Kills (CD3)         2019  01/01/2019        12.9
# 18021  Tottenville and Great Kills (CD3)         2010  01/01/2010        14.7
# 18022               Canarsie - Flatlands         2010  01/01/2010        43.4
# 18023                   Southwest Queens         2010  01/01/2010        65.8
# 18024                            Jamaica         2005  01/01/2005        41.0
#
#        Message
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 18020      NaN
# 18021      NaN
# 18022      NaN
# 18023      NaN
# 18024      NaN
#
# [18025 rows x 12 columns]

# %% [markdown]
# 3. from a file on your computer, specified by the _relative_ path

# %%
pd.read_csv('../Data/Source Data/Air_Quality_20250311.csv')
# Out:
#        Unique ID  Indicator ID                                   Name  \
# 0         179772           640  Boiler Emissions- Total SO2 Emissions
# 1         221956           386                             Ozone (O3)
# 2         221806           386                             Ozone (O3)
# 3         221836           386                             Ozone (O3)
# 4         221812           386                             Ozone (O3)
# ...          ...           ...                                    ...
# 18020     816914           643          Annual vehicle miles traveled
# 18021     816913           643          Annual vehicle miles traveled
# 18022     816872           643          Annual vehicle miles traveled
# 18023     816832           643          Annual vehicle miles traveled
# 18024     151658           643          Annual vehicle miles traveled
#
#               Measure     Measure Info Geo Type Name  Geo Join ID  \
# 0      Number per km2           number         UHF42        409.0
# 1                Mean              ppb         UHF34     305307.0
# 2                Mean              ppb         UHF34        103.0
# 3                Mean              ppb         UHF34        204.0
# 4                Mean              ppb         UHF34        104.0
# ...               ...              ...           ...          ...
# 18020   Million miles  per square mile            CD        503.0
# 18021   Million miles  per square mile            CD        503.0
# 18022   Million miles  per square mile         UHF42        208.0
# 18023   Million miles  per square mile         UHF42        407.0
# 18024   Million miles  per square mile         UHF42        408.0
#
#                           Geo Place Name  Time Period  Start_Date  Data Value  \
# 0                       Southeast Queens         2015  01/01/2015         0.3
# 1               Upper East Side-Gramercy  Summer 2014  06/01/2014        24.9
# 2                     Fordham - Bronx Pk  Summer 2014  06/01/2014        30.7
# 3                          East New York  Summer 2014  06/01/2014        32.0
# 4                   Pelham - Throgs Neck  Summer 2014  06/01/2014        31.9
# ...                                  ...          ...         ...         ...
# 18020  Tottenville and Great Kills (CD3)         2019  01/01/2019        12.9
# 18021  Tottenville and Great Kills (CD3)         2010  01/01/2010        14.7
# 18022               Canarsie - Flatlands         2010  01/01/2010        43.4
# 18023                   Southwest Queens         2010  01/01/2010        65.8
# 18024                            Jamaica         2005  01/01/2005        41.0
#
#        Message
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 18020      NaN
# 18021      NaN
# 18022      NaN
# 18023      NaN
# 18024      NaN
#
# [18025 rows x 12 columns]

# %% [markdown]
# (Relative paths are useful to be able to package up all your code and data for someone else to view on their own computers. With the complete folder (including the same file structure), anyone else will be able to run the same code referencing the same files.)

# %% [markdown]
# ### Some other data formats:

# %% [markdown]
# #### json
#
# - (short for [JavaScript Object Notation](https://en.wikipedia.org/wiki/JSON), but don't memorize that).
# - Follows a structure similar to Python lists and dicts. e.g.:
# ```json
# {
#   "first_name": "John",
#   "last_name": "Smith",
#   "is_alive": true,
#   "age": 27,
#   "address": {
#     "street_address": "21 2nd Street",
#     "city": "New York",
#     "state": "NY",
#     "postal_code": "10021-3100"
#   },
#   "phone_numbers": [
#     {
#       "type": "home",
#       "number": "212 555-1234"
#     },
#     {
#       "type": "office",
#       "number": "646 555-4567"
#     }
#   ],
#   "children": [
#     "Catherine",
#     "Thomas",
#     "Trevor"
#   ],
#   "spouse": null
# }
# ```
#
# - A common format for data passed around websites
# - Not necessarily tabular (i.e. not neatly 2-dimensional), but can represent tabular data. e.g. https://data.cityofnewyork.us/resource/c3uy-2p5r.json

# %% [markdown]
# #### Excel
#
# - Excel files include data, formulas, layouts and formatting of multiple sheets within a binary file that is not human-readable.
# - Can read into pandas, but should specify the sheet and range.

# %%
pd.read_excel('../Data/Source Data/Arraignments_thruJan2025.xlsx')
# Out:
#                  2025 Arraignments (cases continued at arraignment)  \
# 0                 NaN                                 Misd- missing
# 1             January                                             2
# 2            February                                           NaN
# 3               March                                           NaN
# 4               April                                           NaN
# ..                ...                                           ...
# 102          December                                             4
# 103               NaN                                           NaN
# 104           Source:                                           NaN
# 105               CJA                                           NaN
# 106  *updated monthly                                           NaN
#
#        Unnamed: 2    Unnamed: 3        Unnamed: 4 Unnamed: 5     Unnamed: 6  \
# 0    Misd- remand  Misd-$1 bail  Misd- money bail   Misd-ROR  Misd- Sup Rel
# 1               0           314               265       5373           1549
# 2             NaN           NaN               NaN        NaN            NaN
# 3             NaN           NaN               NaN        NaN            NaN
# 4             NaN           NaN               NaN        NaN            NaN
# ..            ...           ...               ...        ...            ...
# 102            17           149               142       4025            239
# 103           NaN           NaN               NaN        NaN            NaN
# 104           NaN           NaN               NaN        NaN            NaN
# 105           NaN           NaN               NaN        NaN            NaN
# 106           NaN           NaN               NaN        NaN            NaN
#
#      Unnamed: 7     Unnamed: 8    Unnamed: 9  ... Unnamed: 19   Unnamed: 20  \
# 0    Misd Total  NVFO- missing  NVFO- remand  ...     VFO-ROR  VFO- Sup Rel
# 1          7503              1            13  ...         346           490
# 2           NaN            NaN           NaN  ...         NaN           NaN
# 3           NaN            NaN           NaN  ...         NaN           NaN
# 4           NaN            NaN           NaN  ...         NaN           NaN
# ..          ...            ...           ...  ...         ...           ...
# 102        4576              1            14  ...         367           162
# 103         NaN            NaN           NaN  ...         NaN           NaN
# 104         NaN            NaN           NaN  ...         NaN           NaN
# 105         NaN            NaN           NaN  ...         NaN           NaN
# 106         NaN            NaN           NaN  ...         NaN           NaN
#
#     Unnamed: 21            Unnamed: 22           Unnamed: 23  \
# 0     VFO Total  Arraignments- missing  Arraignments- remand
# 1          1688                     17                    96
# 2           NaN                    NaN                   NaN
# 3           NaN                    NaN                   NaN
# 4           NaN                    NaN                   NaN
# ..          ...                    ...                   ...
# 102        1010                      7                    69
# 103         NaN                    NaN                   NaN
# 104         NaN                    NaN                   NaN
# 105         NaN                    NaN                   NaN
# 106         NaN                    NaN                   NaN
#
#                Unnamed: 24                  Unnamed: 25       Unnamed: 26  \
# 0    Arraignments- $1 bail  Arraignments-money bail set  Arraignments-ROR
# 1                      394                         1343              6361
# 2                      NaN                          NaN               NaN
# 3                      NaN                          NaN               NaN
# 4                      NaN                          NaN               NaN
# ..                     ...                          ...               ...
# 102                    221                          745              5129
# 103                    NaN                          NaN               NaN
# 104                    NaN                          NaN               NaN
# 105                    NaN                          NaN               NaN
# 106                    NaN                          NaN               NaN
#
#                Unnamed: 27         Unnamed: 28
# 0    Arraignments- Sup Rel  Arraignments Total
# 1                     2732               10943
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ..                     ...                 ...
# 102                    611                6782
# 103                    NaN                 NaN
# 104                    NaN                 NaN
# 105                    NaN                 NaN
# 106                    NaN                 NaN
#
# [107 rows x 29 columns]

# %%
pd.read_excel(
    '../Data/Source Data/Arraignments_thruJan2025.xlsx',
    sheet_name='Arraignments HISTORICAL',
    header=1
)
# Out:
#     Year  Misdemeanor/ Violation  Nonviolent felony  Violent Felony    Remand  \
# 0   1993                   61121              53514           36445  0.020000
# 1   1994                   77741              57191           36125  0.020000
# 2   1995                   82152              58089           34588  0.020000
# 3   1996                   87933              57551           30398  0.020000
# 4   1997                   96113              54698           28820  0.020000
# 5   1998                   92091              54909           27117  0.020000
# 6   1999                   89762              47088           23147  0.020000
# 7   2000                  102020              43538           21518  0.020000
# 8   2001                   93190              37728           20350  0.020000
# 9   2002                   94435              37771           19931  0.020000
# 10  2003                   97375              32632           19718  0.020000
# 11  2004                  100309              34078           19091  0.020000
# 12  2005                   99101              35696           19422  0.020000
# 13  2006                  107592              37984           21020  0.020000
# 14  2007                  117024              38834           21902  0.020000
# 15  2008                  119849              36513           22589  0.020000
# 16  2009                  123252              34201           20915  0.020000
# 17  2010                  121089              31777           20622  0.010000
# 18  2011                  117450              29985           20461  0.010000
# 19  2012                  119904              29530           20082  0.020000
# 20  2013                  121829              30601           19349  0.010000
# 21  2014                  119516              30895           17840  0.010000
# 22  2015                  109230              29592           18209  0.010000
# 23  2016                  107670              28907           17800  0.020000
# 24  2017                  100048              25626           16525  0.020000
# 25  2018                   94687              22508           15335  0.010000
# 26  2019                   86392              19286           14243  0.010000
# 27  2020                   41759              11590           13703  0.008784
# 28  2021                   49204              11897           15108  0.010000
# 29  2022                   61945              14194           17191  0.010000
# 30  2023                   71234              17950           19703  0.010000
# 31  2024                   79932              20345           21761  0.010000
#
#     Bail Set       ROR  Supervised Release  Unnamed: 8  Unnamed: 9  \
# 0   0.460000  0.520000                 NaN         NaN         NaN
# 1   0.460000  0.530000                 NaN         NaN         NaN
# 2   0.440000  0.540000                 NaN         NaN         NaN
# 3   0.460000  0.520000                 NaN         NaN         NaN
# 4   0.430000  0.550000                 NaN         NaN         NaN
# 5   0.440000  0.550000                 NaN         NaN         NaN
# 6   0.430000  0.550000                 NaN         NaN         NaN
# 7   0.420000  0.570000                 NaN         NaN         NaN
# 8   0.410000  0.570000                 NaN         NaN         NaN
# 9   0.410000  0.570000                 NaN         NaN         NaN
# 10  0.390000  0.590000                 NaN         NaN         NaN
# 11  0.370000  0.610000                 NaN         NaN         NaN
# 12  0.380000  0.600000                 NaN         NaN         NaN
# 13  0.370000  0.610000                 NaN         NaN         NaN
# 14  0.370000  0.620000                 NaN         NaN         NaN
# 15  0.350000  0.640000                 NaN         NaN         NaN
# 16  0.330000  0.650000                 NaN         NaN         NaN
# 17  0.310000  0.670000                 NaN         NaN         NaN
# 18  0.310000  0.670000                 NaN         NaN         NaN
# 19  0.310000  0.670000                 NaN         NaN         NaN
# 20  0.300000  0.680000                 NaN         NaN         NaN
# 21  0.290000  0.690000                 NaN         NaN         NaN
# 22  0.290000  0.700000                 NaN         NaN         NaN
# 23  0.280000  0.690000            0.020000         NaN         NaN
# 24  0.280000  0.680000            0.030000         NaN         NaN
# 25  0.230000  0.720000            0.040000         NaN         NaN
# 26  0.190000  0.750000            0.040000         NaN         NaN
# 27  0.169152  0.692209            0.110064         NaN         NaN
# 28  0.180000  0.640000            0.170000         NaN         NaN
# 29  0.160000  0.610000            0.210000         NaN         NaN
# 30  0.160000  0.600000            0.230000         NaN         NaN
# 31  0.160000  0.590000            0.240000         NaN         NaN
#
#     Unnamed: 10                                             Source
# 0           NaN  *1993-2019 https://www.nycja.org/publications/...
# 1           NaN  2020 - 2024:calculated from monthly tab, origi...
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# 13          NaN                                                NaN
# 14          NaN                                                NaN
# 15          NaN                                                NaN
# 16          NaN                                                NaN
# 17          NaN                                                NaN
# 18          NaN                                                NaN
# 19          NaN                                                NaN
# 20          NaN                                                NaN
# 21          NaN                                                NaN
# 22          NaN                                                NaN
# 23          NaN                                                NaN
# 24          NaN                                                NaN
# 25          NaN                                                NaN
# 26          NaN                                                NaN
# 27          NaN                                                NaN
# 28          NaN                                                NaN
# 29          NaN                                                NaN
# 30          NaN                                                NaN
# 31          NaN                                                NaN

# %% [markdown]
# ## Writing data

# %% [markdown]
# dataframe's `.to_csv()` method will write out data to a csv file.
#
# - include an absolute or relative file name to save to
# - (default will save index column, pass `index=False` to skip it)

# %% [markdown]
# `.to_clipboard()` method will copy data to clipboard (to paste into Excel or Google Sheets or a document)

# %% [markdown]
# `.to_excel()` method will save excel file
#
# - can add formatting, etc. - for example to automate a process and create a report from a template
